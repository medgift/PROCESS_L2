# %%
import h5py 
"""
H5py:
The h5py package is a Pythonic interface to the HDF5 binary data format.

It lets you store huge amounts of numerical data, and easily manipulate that data from NumPy. 
For example, you can slice into multi-terabyte datasets stored on disk, as if they were real NumPy arrays. 
Thousands of datasets can be stored in a single file, categorized and tagged however you want.
"""
import numpy as np
import os

# %% [raw]
# The results of the dense coverage of the WSIs in Camelyon17 are at this path:
# '/mnt/nas4/datasets/ToReadme/PROCESS/denseSampling/uc1-results/'
# The file system looks like this:
#
# INFO.log       l5_c0_p015_n1  l5_c1_p020_n2  l5_c1_p034_n3  l5_c2_p042_n3  l5_c2_p051_n2  l5_c3_p066_n2
# config.ini     l5_c0_p015_n2  l5_c1_p020_n4  l5_c1_p036_n3  l5_c2_p044_n4  l5_c2_p052_n1  l5_c3_p067_n4
# l5_c0_p004_n4  l5_c0_p016_n1  l5_c1_p021_n3  l5_c1_p038_n2  l5_c2_p045_n1  l5_c3_p060_n3  l5_c3_p068_n1
# l5_c0_p009_n1  l5_c0_p017_n1  l5_c1_p022_n4  l5_c1_p039_n1  l5_c2_p046_n3  l5_c3_p061_n4  l5_c3_p072_n0
# l5_c0_p010_n4  l5_c0_p017_n2  l5_c1_p024_n1  l5_c2_p040_n2  l5_c2_p046_n4  l5_c3_p062_n2  l5_c3_p073_n1
# l5_c0_p012_n0  l5_c0_p017_n4  l5_c1_p024_n2  l5_c2_p041_n0  l5_c2_p048_n1  l5_c3_p064_n0  l5_c3_p075_n4
#
# where the l5_* are folders.
# The naming structure stands for:
# l = level of resolution, 5 for all
# c = center of acquisition, integer from 0 to 3
# p = patient number, integer from 000 to 100
# n = node number, integer from 0 to 4
#
# Each l5_ * folder has this structure:
#
# annotation_mask.png  normal_tissue_mask.png  patches.h5  tumor_locations_0000.png
#
# The *.png files are just for data validation. annotation_mask.png shows a low-res visualization of the clinicians' annotations of tumor areas. normal_tissue_mask.png shows the non-tumor tissue. tumor_locations_0000.png shows where the patches were extracted from. In this case, since we applied a linear window covering all locations in the WSI, the tumor locations cover every image corner.
#
# The file with the image data is patches.h5
#
# I will show in the following how to load it and access to the patches

# %%
# This is the command to open the file. 
# Very important is to ALWAYS add the 'r' condition to avoid overriding the data!
h5 = h5py.File('/mnt/nas4/datasets/ToReadme/PROCESS/denseSampling/uc1-results/l5_c0_p004_n4/patches.h5', 'r')

# %%
# The first file in the data folder is now loaded in the RAM, and we can start inspecting the way it is structured
# We create a list that will contain all the entries in the file. 
# We make this global so that it is accessible from any fuction, anywhere in the code
global dblist
dblist=[]
def list_entries(name, obj):
        if 'patches' in name:
            dblist.append(name)
# visititems is the function to visit all the file entries, the function list_entries will creat the lisdt            
h5.visititems(list_entries)

# %%
# The visititems operation can take a while if the h5 file is large. 
# We now inspect the list of files
print "There are {} entries in the h5py file".format(len(dblist))
print "The patches for the first entry in the file are at this link within the h5py: {}".format(dblist[0])
# Out:
# There are 1464 entries in the h5py file
# The patches for the first entry in the file are at this link within the h5py: normal/l5/c0/p004/n4/0/patches

