# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
folder='results/baseline_auc_fix/'

# %%
log = np.load('{}/training_log.npy'.format(folder), allow_pickle=True).item()

# %%
log.keys()
# Out:
# ['loss', 'lr', 'val_loss', 'my_accuracy', 'val_my_accuracy']

# %%
plt.plot(log['my_accuracy'])
plt.plot(log['val_my_accuracy'])

# %%
plt.plot(log['loss'])
plt.plot(log['val_loss'])

# %%
plt.plot(log['lr'])
